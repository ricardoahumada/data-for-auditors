# %% [markdown]
# # **WinPython**
#
# ### ¿Qué es WinPython?
#
# **WinPython** es una distribución portátil de Python para Windows que incluye:
# - El intérprete de Python
# - Librerías científicas (NumPy, pandas, matplotlib, etc.)
# - **Jupyter Notebook / Jupyter Lab**
# - Spyder, VS Code portable (en algunas versiones)
# - Y todo **sin necesidad de instalar nada**: se ejecuta desde una carpeta (¡incluso desde un USB!).
#
#
# ## **Usar WinPython en modo portable**
#
# ### 1. **Descargar WinPython**
#
# 1. Ve a la página oficial:
#    https://winpython.github.io/
# 2. Descarga la versión **"WinPython64"** (o **32** si usas Windows de 32 bits) en formato **`.exe`** o **`.zip`**.
#    - Recomendado: **versión "Zero"** si solo quieres lo esencial (más ligera).
#    - Ejemplo: `WinPython64-3.11.9.0.exe` (Python 3.11 + paquetes básicos).
# 3. **Ejecuta el `.exe`** (no se instala en el sistema):
#    - Simplemente extrae los archivos a una carpeta de tu elección (ej. `D:\WinPython` o `C:\Tools\WinPython`).
#    - **No requiere permisos de administrador**.
#
# > 💡 Si descargas el `.zip`, descomprímelo donde quieras.
#
#
# ### 2. **Estructura de la carpeta**
#
# Después de extraer, verás algo como:
#
# ```
# WinPython/
# ├── python-3.11.9/       ← entorno de Python
# ├── scripts/             ← lanzadores útiles
# ├── settings/            ← configuración (Jupyter, pip, etc.)
# ├── notebook.bat         ← abre Jupyter Notebook
# ├── jupyter_lab.bat      ← abre Jupyter Lab
# ├── winpython.bat        ← abre terminal con Python en PATH
# └── ...
# ```
#
#
# ### 3. **Ejecutar Jupyter Notebook**
#
# - **Doble clic** en:
#   - `notebook.bat` → abre **Jupyter Notebook** en tu navegador.
#   - `jupyter_lab.bat` → abre **Jupyter Lab** (interfaz más moderna).
#
# > Se abrirá automáticamente una pestaña en tu navegador (normalmente `http://localhost:8888`).
#
# - Los notebooks se guardarán **donde los crees** (por defecto, en la carpeta de WinPython, pero puedes navegar a cualquier ubicación).
#
#
# ### 4. **Ejecutar scripts de Python**
#
# #### Opción A: Usar la terminal de WinPython
# 1. Haz doble clic en `winpython.bat`.
# 2. Se abre una consola con Python ya en el `PATH`.
# 3. Ejecuta:
#    ```bash
#    python mi_script.py
#    ```
#
# #### Opción B: Arrastrar y soltar (rápido)
# - Arrastra tu archivo `.py` sobre `python.exe` (dentro de `python-3.x.x/`) → se ejecutará (la ventana puede cerrarse rápido; úsalo solo para pruebas).
#
# #### Opción C: Usar un editor
# - Puedes usar **VS Code** o cualquier editor externo.
# - En la terminal (`winpython.bat`), navega a la carpeta de tu script y ejecútalo.
#
#
# ### 5. **Instalar paquetes adicionales**
#
# WinPython incluye `pip`, pero **usa el lanzador incluido** para evitar problemas:
#
# 1. Abre `winpython.bat` (terminal con entorno activado).
# 2. Ejecuta:
#    ```bash
#    pip install nombre_del_paquete
#    ```
#    Ejemplo:
#    ```bash
#    pip install requests
#    ```
#
# > **No uses el `pip` del sistema**, solo el de WinPython.
#
# Los paquetes se instalan en la carpeta portátil → **todo sigue siendo portable**.
#
#
# ### Consejos útiles
#
# - **Evita espacios en la ruta**: usa `D:\WinPython`, no `D:\Mis Herramientas\WinPython`.
# - **Actualiza paquetes con cuidado**: `pip install --upgrade nombre_paquete`.
# - **Guarda tus notebooks en una carpeta separada** (ej. `D:\MisProyectos`) para no mezclarlos con los archivos de WinPython.
# - Usa **Jupyter Lab** en lugar de Notebook si quieres una experiencia más moderna (editor de texto, terminal integrado, etc.).
